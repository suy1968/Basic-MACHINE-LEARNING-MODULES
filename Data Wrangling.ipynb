# %% [markdown]
# # SUYASH PRATAP SINGH

# %% [markdown]
# # Data Wrangling
# About the notebook: In this notebook, I have covered some important aspects of data wrangling these concepts certainly making me to wrangle the data from any ways.
#
#
# About Data Wrangling(sometimes referred to as data munging): Data wrangling is used to describe the process of transforming raw data to a clean and organized formate ready for use data. Data wrangling is the process of cleaning and unifying messy and complex data sets for easy access and analysis.

# %% [markdown]
# # List of Operations Performed
# 1.Creating a Data Frame
# 2.Describing the Data
# 3.Navigating DataFrames
# 4.Selecting Rows Based on Conditionals
# 5.Replacing Values
# 6.Renaming Columns
# 7.Finding the Minimum, Maximum, Sum, Average, and Count
# 8.Finding Unique Values
# 9.Handling Missing Values
# 10.Deleting a Column
# 11.Deleting a Row
# 12.Dropping Duplicate Rows
# 13.Grouping Rows by Values
# 14.Grouping Rows by Time
# 15.Looping Over a Column
# 16.Applying a Function Over All Elements in a Column
# 17.Applying a Function to Groups
# 18.Concatenating DataFrames
# 19.Merging DataFrames

# %% [markdown]
# # 1. Creating dataframe

# %%
# laod library
import pandas as pd
import numpy as np

# %%
# create dataframe
dataframe = pd.DataFrame()
dataframe
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# add columns
dataframe['name'] = ['suyash', 'tejas']
dataframe['age'] = [20,21]
dataframe['student']= [True, False]

# %%
# show dataframe
dataframe
# Out:
#      name  age  student
# 0  suyash   20     True
# 1   tejas   21    False

# %%
# create row
new_row = pd.Series(['Vineet', 22, True], index = ['name', 'age', 'student'])

# %%
#append row
dataframe.append(new_row,ignore_index= True)
# Out:
#      name  age  student
# 0  suyash   20     True
# 1   tejas   21    False
# 2  Vineet   22     True

# %% [markdown]
# # 2. Describing the data

# %%
#select first two rows
dataframe.head(2)
# Out:
#      name  age  student
# 0  suyash   20     True
# 1   tejas   21    False

# %%
# show dimensions
dataframe.shape
# Out:
# (2, 3)

# %%
# show statistics
dataframe.describe()
# Out:
#              age
# count   2.000000
# mean   20.500000
# std     0.707107
# min    20.000000
# 25%    20.250000
# 50%    20.500000
# 75%    20.750000
# max    21.000000

# %%
#full dataframe 
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2 non-null      object
#  1   age      2 non-null      int64
#  2   student  2 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 162.0+ bytes

# %% [markdown]
# # 3. Navigating Dataframes

# %%
# load library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# load data
df = pd.read_csv(r'C:\Users\Admin\Desktop\train(suyash).csv')

# %%
# select first row
df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
# select first two rows
df.iloc[0:1]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
# select first five rows
df.iloc[0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# set index
df = df.set_index(df['Name']) # by default indexes are integer, we set here as string (name)

# %%
# show row
df.loc['Allen, Miss. Elisabeth Walton'] # returns by name as index
# Out:
# PassengerId                              731
# Survived                                   1
# Pclass                                     1
# Name           Allen, Miss. Elisabeth Walton
# Sex                                   female
# Age                                       29
# SibSp                                      0
# Parch                                      0
# Ticket                                 24160
# Fare                                 211.338
# Cabin                                     B5
# Embarked                                   S
# Name: Allen, Miss. Elisabeth Walton, dtype: object

# %%
# show first index
df.iloc[0] # returns first row regardless of whether index is an interger or a label
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: Braund, Mr. Owen Harris, dtype: object

# %% [markdown]
# # 4. Selecting rows based on conditinals

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass  \
# Name
# ...

# %%
# show top two rows where column 'sex' is female (single row selection)
df[df['Sex']=='female'].head(2)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
#
#                                                     Pclass  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
#
#                                                                                                  Name  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
# Heikkinen, Miss. Laina                                                         Heikkinen, Miss. Laina
#
#                                                        Sex   Age  SibSp  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1
# Heikkinen, Miss. Laina                              female  26.0      0
#
# ...

# %%
# multiples row selection
df[(df['Sex']=='female') & (df['Age']>=62)]
# Out:
#                                            PassengerId  Survived  Pclass  \
# Name
# Andrews, Miss. Kornelia Theodosia                  276         1       1
# Turkula, Mrs. (Hedwig)                             484         1       3
# Stone, Mrs. George Nelson (Martha Evelyn)          830         1       1
#
#                                                                                 Name  \
# Name
# Andrews, Miss. Kornelia Theodosia                  Andrews, Miss. Kornelia Theodosia
# Turkula, Mrs. (Hedwig)                                        Turkula, Mrs. (Hedwig)
# Stone, Mrs. George Nelson (Martha Evelyn)  Stone, Mrs. George Nelson (Martha Evelyn)
#
#                                               Sex   Age  SibSp  Parch  Ticket  \
# Name
# Andrews, Miss. Kornelia Theodosia          female  63.0      1      0   13502
# Turkula, Mrs. (Hedwig)                     female  63.0      0      0    4134
# ...

# %% [markdown]
# # 5.Replacing values

# %%
# replace female as woman
df['Sex'].replace('female', 'woman').head(2)
# Out:
# Name
# Braund, Mr. Owen Harris                                 male
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    woman
# Name: Sex, dtype: object

# %%
# replace female as woman and male as man
df['Sex'].replace(['female', 'male'], ['woman', 'man']).head(2)
# Out:
# Name
# Braund, Mr. Owen Harris                                  man
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    woman
# Name: Sex, dtype: object

# %%
# view dataframe
df.head(2)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
#
#                                                                                                  Name  \
# Name
# Braund, Mr. Owen Harris                                                       Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                                                        Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris                               male  22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1
#
# ...

# %%
# replacing for entire dataframe
df.replace(['female', 'male'], ['woman', 'man'])
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass  \
# Name
# ...

# %% [markdown]
# # 6. Renaming columns names

# %%
df.rename(columns={'Sex':'gender'})
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass  \
# Name
# ...

# %% [markdown]
# # 7.Find minimum, maximum, sum, average, count

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].count()
# Out:
# 714

# %%
df['Age'].sum()
# Out:
# 21205.17

# %% [markdown]
# # Find Statistics

# %%
df['Age'].var() # variance
# Out:
# 211.01912474630802

# %%
df['Age'].std() # standard deviation
# Out:
# 14.526497332334042

# %%
df['Age'].skew # skewness
# Out:
# <bound method Series.skew of Name
# Braund, Mr. Owen Harris                                22.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    38.0
# Heikkinen, Miss. Laina                                 26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           35.0
# Allen, Mr. William Henry                               35.0
#                                                        ...
# Montvila, Rev. Juozas                                  27.0
# Graham, Miss. Margaret Edith                           19.0
# Johnston, Miss. Catherine Helen "Carrie"                NaN
# Behr, Mr. Karl Howell                                  26.0
# Dooley, Mr. Patrick                                    32.0
# Name: Age, Length: 891, dtype: float64>

# %%
df['Age'].sem()  # standard error of mean
# Out:
# 0.5436404994496713

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df['Age'].mode()
# Out:
# 0    24.0
# dtype: float64

# %%
df['Age'].mode()
# Out:
# 0    24.0
# dtype: float64

# %% [markdown]
# # 8. Finding unique values

# %%
df['Age'].unique() # veiw an array of all unique values in a column
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df['Age'].value_counts() # displays all unique values with no. of times each values appears
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
df['Age'].nunique() # finds total no. of unique values
# Out:
# 88

# %% [markdown]
# # 9.Handling Missing Values

# %%
df.isnull().sum() # returns null values content
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.notnull().sum() # return not null values contents
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# Replace values with NaN
import numpy as np
df['Sex'] = df['Sex'].replace('male', np.nan)

# %%
df.head(3)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
#
#                                                                                                  Name  \
# Name
# Braund, Mr. Owen Harris                                                       Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
# Heikkinen, Miss. Laina                                                         Heikkinen, Miss. Laina
#
# ...

# %% [markdown]
# # 10. Delete a column

# %%
# a single column
df.drop('Age', axis=1).head(2)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
#
#                                                                                                  Name  \
# Name
# Braund, Mr. Owen Harris                                                       Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                                                        Sex  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                NaN      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female      1      0
#
# ...

# %%
# multiple column
df.drop(['Parch','Ticket'], axis=1).head(2)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
#
#                                                                                                  Name  \
# Name
# Braund, Mr. Owen Harris                                                       Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                                                        Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris                                NaN  22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1
#
# ...

# %%
# delete by column index
df.drop(df.columns[0], axis=1).head(2)
# Out:
#                                                     Survived  Pclass  \
# Name
# Braund, Mr. Owen Harris                                    0       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1
#
#                                                                                                  Name  \
# Name
# Braund, Mr. Owen Harris                                                       Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                                                        Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris                                NaN  22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1
#
#                                                     Parch     Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                 0  A/5 21171   7.2500
# ...

# %% [markdown]
# # 11.Deleting Rows

# %%
df[df['Sex']!='female']  # conditional method
# Out:
#                                 PassengerId  Survived  Pclass  \
# Name
# Braund, Mr. Owen Harris                   1         0       3
# Allen, Mr. William Henry                  5         0       3
# Moran, Mr. James                          6         0       3
# McCarthy, Mr. Timothy J                   7         0       1
# Palsson, Master. Gosta Leonard            8         0       3
# ...                                     ...       ...     ...
# Banfield, Mr. Frederick James           884         0       2
# Sutehall, Mr. Henry Jr                  885         0       3
# Montvila, Rev. Juozas                   887         0       2
# Behr, Mr. Karl Howell                   890         1       1
# Dooley, Mr. Patrick                     891         0       3
#
#                                                           Name  Sex   Age  \
# Name
# Braund, Mr. Owen Harris                Braund, Mr. Owen Harris  NaN  22.0
# ...

# %%
df.tail(4)#print last four row
# Out:
#                                           PassengerId  Survived  Pclass  \
# Name
# Graham, Miss. Margaret Edith                      888         1       1
# Johnston, Miss. Catherine Helen "Carrie"          889         0       3
# Behr, Mr. Karl Howell                             890         1       1
# Dooley, Mr. Patrick                               891         0       3
#
#                                                                               Name  \
# Name
# Graham, Miss. Margaret Edith                          Graham, Miss. Margaret Edith
# Johnston, Miss. Catherine Helen "Carrie"  Johnston, Miss. Catherine Helen "Carrie"
# Behr, Mr. Karl Howell                                        Behr, Mr. Karl Howell
# Dooley, Mr. Patrick                                            Dooley, Mr. Patrick
#
#                                              Sex   Age  SibSp  Parch  \
# Name
# Graham, Miss. Margaret Edith              female  19.0      0      0
# ...

# %%
df.sample(9)  #print random five row
# Out:
#                                                     PassengerId  Survived  \
# Name
# Spedden, Mrs. Frederic Oakley (Margaretta Corni...          320         1
# Foreman, Mr. Benjamin Laventall                             453         0
# Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)           54         1
# Naidenoff, Mr. Penko                                        288         0
# Ryerson, Miss. Susan Parker "Suzette"                       743         1
# Phillips, Miss. Kate Florence ("Mrs Kate Louise...          428         1
# Harris, Mrs. Henry Birkhardt (Irene Wallach)                231         1
# Ohman, Miss. Velin                                          555         1
# Skoog, Master. Karl Thorsten                                820         0
#
#                                                     Pclass  \
# Name
# Spedden, Mrs. Frederic Oakley (Margaretta Corni...       1
# Foreman, Mr. Benjamin Laventall                          1
# ...

# %%
df.drop(['Allen, Miss. Elisabeth Walton']).head(2) # delete first two rows
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
#
#                                                                                                  Name  \
# Name
# Braund, Mr. Owen Harris                                                       Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                                                        Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris                                NaN  22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1
#
# ...

# %% [markdown]
# # 12. Dropping duplicate rows

# %%
df.drop_duplicates().head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# Allen, Mr. William Henry                                 3
#
#                                                                                                  Name  \
# Name
# ...

# %% [markdown]
# # 13.Grouping Rows by values

# %%
df.groupby('Sex').mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
#
#              Fare
# Sex
# female  44.479818

# %%
df.groupby('Age').mean()
# Out:
#        PassengerId  Survived  Pclass  SibSp  Parch      Fare
# Age
# 0.42         804.0       1.0     3.0    0.0    1.0    8.5167
# 0.67         756.0       1.0     2.0    1.0    1.0   14.5000
# 0.75         557.5       1.0     3.0    2.0    1.0   19.2583
# 0.83         455.5       1.0     2.0    0.5    1.5   23.8750
# 0.92         306.0       1.0     1.0    1.0    2.0  151.5500
# ...            ...       ...     ...    ...    ...       ...
# 70.00        709.5       0.0     1.5    0.5    0.5   40.7500
# 70.50        117.0       0.0     3.0    0.0    0.0    7.7500
# 71.00        295.5       0.0     1.0    0.0    0.0   42.0792
# 74.00        852.0       0.0     3.0    0.0    0.0    7.7750
# 80.00        631.0       1.0     1.0    0.0    0.0   30.0000
#
# [88 rows x 6 columns]

# %%
df.groupby('Sex').median()
# Out:
#         PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare
# Sex
# female        414.5       1.0     2.0  27.0    0.0    0.0  23.0

# %% [markdown]
# # 14. Grouping Rows by time

# %%
# Create date range
time_index = pd.date_range('11/10/2020', periods=100000, freq='30S')

# %%
# Create DataFrame
dataframe = pd.DataFrame(index=time_index)

# %%
#Create column of random values
dataframe['Sale_Amount'] = np.random.randint(1, 10, 100000)

# %%
# Group rows by week, calculate sum per week
dataframe.resample('W').sum()
# Out:
#             Sale_Amount
# 2020-11-15        86798
# 2020-11-22       100828
# 2020-11-29       100495
# 2020-12-06       101117
# 2020-12-13       100634
# 2020-12-20        10341

# %%
# Show three rows
dataframe.head(3)
# Out:
#                      Sale_Amount
# 2020-11-10 00:00:00            8
# 2020-11-10 00:00:30            8
# 2020-11-10 00:01:00            7

# %%
# Group by two weeks, calculate mean
dataframe.resample('2W').mean()
# Out:
#             Sale_Amount
# 2020-11-15     5.023032
# 2020-11-29     4.993130
# 2020-12-13     5.003745
# 2020-12-27     4.971635

# %%
# Group by month, count rows
dataframe.resample('M').count()
# Out:
#             Sale_Amount
# 2020-11-30        60480
# 2020-12-31        39520

# %%
#Group by month, count rows
dataframe.resample('M', label='left').count()
# Out:
#             Sale_Amount
# 2020-10-31        60480
# 2020-11-30        39520

# %% [markdown]
# # 15. Looping Over a Column

# %%
# Print first two names uppercased
for name in df['Name'][0:2]:
    print(name.upper())
# Out:
# BRAUND, MR. OWEN HARRIS
# CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS THAYER)

# %% [markdown]
# # 16.Applying a Function Over All Elements in a Column

# %%
# Create a dataframe from a list of dictionaries
rectangles = [
    { 'height': 40, 'width': 10 },
    { 'height': 20, 'width': 9 },
    { 'height': 3.4, 'width': 4 }
]

rectangles_df = pd.DataFrame(rectangles)
rectangles_df
# Out:
#    height  width
# 0    40.0     10
# 1    20.0      9
# 2     3.4      4

# %%
# Use the height and width to calculate the area
def calculate_area(row):
    return row['height'] * row['width']

rectangles_df.apply(calculate_area, axis=1)
# Out:
# 0    400.0
# 1    180.0
# 2     13.6
# dtype: float64

# %%
# Use .apply to save the new column if we'd like
rectangles_df['area'] = rectangles_df.apply(calculate_area, axis=1)
rectangles_df
# Out:
#    height  width   area
# 0    40.0     10  400.0
# 1    20.0      9  180.0
# 2     3.4      4   13.6

# %% [markdown]
# # 17.Applying a Function to Groups

# %%
# Group rows, apply function to groups
df.groupby('Sex').apply(lambda x: x.count())
# Out:
#         PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Sex
# female          314       314     314   314  314  261    314    314     314
#
#         Fare  Cabin  Embarked
# Sex
# female   314     97       312

# %% [markdown]
# # 18.Concatenating DataFrames

# %%
# Create DataFrame
data_a = {'id': ['1', '2', '3'],
'first': ['Alex', 'Amy', 'Allen'],
'last': ['Anderson', 'Ackerman', 'Ali']}
dataframe_a = pd.DataFrame(data_a, columns = ['id', 'first', 'last'])
# Create DataFrame
data_b = {'id': ['4', '5', '6'],
'first': ['Billy', 'Brian', 'Bran'],
'last': ['Bonder', 'Black', 'Balwner']}
dataframe_b = pd.DataFrame(data_b, columns = ['id', 'first', 'last'])

# %%
# Concatenate DataFrames by rows
pd.concat([dataframe_a, dataframe_b], axis=0)
# Out:
#   id  first      last
# 0  1   Alex  Anderson
# 1  2    Amy  Ackerman
# 2  3  Allen       Ali
# 0  4  Billy    Bonder
# 1  5  Brian     Black
# 2  6   Bran   Balwner

# %% [markdown]
# # 19.Merging DataFrames

# %%
# Create DataFrame
employee_data = {'employee_id': ['1', '2', '3', '4'],
'name': ['Amy Jones', 'Allen Keys', 'Alice Bees',
'Tim Horton']}
dataframe_employees = pd.DataFrame(employee_data, columns = ['employee_id',
'name'])
# Create DataFrame
sales_data = {'employee_id': ['3', '4', '5', '6'],
'total_sales': [23456, 2512, 2345, 1455]}
dataframe_sales = pd.DataFrame(sales_data, columns = ['employee_id',
'total_sales'])

# %%
# Merge DataFrames
pd.merge(dataframe_employees, dataframe_sales, on='employee_id')
# Out:
#   employee_id        name  total_sales
# 0           3  Alice Bees        23456
# 1           4  Tim Horton         2512

# %% [markdown]
# # THANK YOU
